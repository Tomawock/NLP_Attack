# %% [markdown]
# <a href="https://colab.research.google.com/github/Tomawock/NLP_Attack/blob/main/evaluate_models/DDI_base_model_optuna_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install optuna

# %%
import optuna

# %% [markdown]
# Load the study from diive

# %%
ddi_study = optuna.load_study(study_name="DDI", storage="sqlite:////content/drive/Shareddrives/Deep Learning/datasets/DDI/ddi2013-type/optuna_ddi_models.db")

# %% [markdown]
# grafici andamento optuna

# %%
optuna.visualization.plot_optimization_history(ddi_study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6d8c58fc-2013-463e-a389-66a90af688a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6d8c58fc-2013-463e-a389-66a90af688a6")) {
#                     Plotly.newPlot(
#                         '6d8c58fc-2013-463e-a389-66a90af688a6',
# ...

# %%
optuna.visualization.plot_slice(ddi_study, params=['batch_size', 'units', 'dropout'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9cb232a6-43ae-4681-9385-990a823926d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9cb232a6-43ae-4681-9385-990a823926d5")) {
#                     Plotly.newPlot(
#                         '9cb232a6-43ae-4681-9385-990a823926d5',
# ...

# %%
optuna.visualization.plot_param_importances(ddi_study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="eefa6e7a-f196-4400-8022-8a6460637a97" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eefa6e7a-f196-4400-8022-8a6460637a97")) {
#                     Plotly.newPlot(
#                         'eefa6e7a-f196-4400-8022-8a6460637a97',
# ...
